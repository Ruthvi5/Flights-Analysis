# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# Load & Inspect
df = pd.read_csv("flight_delay.csv")

df.head()
# Out:
#     Used Date From   To   Airline Scheduled Departure  SDEP Departure   DEP  \
# 0  31-01-2020  DEL  HYD  Air Asia               06:05   605     06:04   604
# 1  31-01-2020  DEL  HYD    Indigo               04:50   450     04:36   436
# 2  30-01-2020  DEL  HYD  Air Asia               06:05   605     05:54   554
# 3  30-01-2020  DEL  HYD  Air Asia               17:40  1740     17:40  1740
# 4  30-01-2020  DEL  HYD  Air Asia               19:50  1950     19:54  1954
#
#   Scheduled Arrival  SARR  ... Market Share  OTP Index  \
# 0             08:15   815  ...          5.3       85.6
# 1             07:00   700  ...         47.5       81.1
# 2             08:15   815  ...          5.3       85.6
# 3             19:55  1955  ...          5.3       85.6
# 4             22:10  2210  ...          5.3       85.6
#
#    weather__hourly__windspeedKmph  weather__hourly__weatherDesc__value  \
# 0                              11                        Partly cloudy
# ...

# %%
df.isna().sum()
# Out:
# Used Date                              0
# From                                   0
# To                                     0
# Airline                                0
# Scheduled Departure                    0
# SDEP                                   0
# Departure                              0
# DEP                                    0
# Scheduled Arrival                      0
# SARR                                   0
# Arrival                                0
# ARR                                    0
# Departure Delay                        0
# Arrival Delay                          0
# Status                                 0
# Distance                               0
# Passenger Load Factor                  0
# Airline Rating                         0
# Airport Rating                         0
# Market Share                           0
# OTP Index                              0
# weather__hourly__windspeedKmph         0
# weather__hourly__weatherDesc__value    0
# ...

# %%
df['delay_rate'] = (df['Dep_Delay_Minutes']+df['Arr_Delay_Minutes'])/2
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Dep_Delay_Minutes'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[6], line 1
# ...
